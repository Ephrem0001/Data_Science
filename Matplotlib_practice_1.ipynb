# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
point = np.array([3,5,7,2,7,29,9])

# %%
plt.plot(point)
plt.show()

# %%
point2 = np.array([3,5,7,2,7,29,9])

# %%
plt.plot(point, linestyle = "dashed")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
